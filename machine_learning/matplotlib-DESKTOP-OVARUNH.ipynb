# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import numpy as np
from scipy import datasets

# %%
x = np.linspace(0, 10, 15)
y = x**2

# %% [markdown]
# Il faut que les deux variables soit correspondantes (de même taille).

# %%
plt.plot(x, y, c='red', lw=3, ls='--') # lw (line width) ls (line style)
# plt.scatter(x, y)

# %% [markdown]
# ### Les basiques

# %%
plt.figure(figsize=(6, 4)) # Début de la figure : la fenétre de travail sur laquel travailler. Attribue figsize pour régler la taille.
plt.plot(x, y, label='quadratique') # Contenu 1
plt.plot(x, x**3, c='red', label='cubique') # Contenu 2…
plt.xlabel('X') # Les labels
plt.ylabel('Y')
plt.title("X vs X**2")
plt.legend() # Pour utiliser cet argument, il faut le préciser dans la création du graphique
plt.show() # Affiche la figure

# %% [markdown]
# ### Les subplot's

# %% [markdown]
# ![subplot](matpoltlib_png/subplot.png "subplot")

# %%
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x, y, c='red')
plt.title("Red figure")
plt.subplot(2, 1, 2)
plt.plot(x, np.sin(x), label='sinus de x')
plt.plot(x, np.cos(x), label='cosinus de y')
plt.legend() # Afficher les labels
# plt.title("Blue figure")
plt.show()

# %% [markdown]
# ## POO matplotlib

# %%
face = datasets.face(gray=True)
# plt.imshow(face, cmap='gray')
plt.hist(face.ravel(), bins=255)
# Out:
# (array([2.900e+01, 6.600e+01, 5.700e+01, 1.300e+02, 3.920e+02, 8.390e+02,
#         1.841e+03, 2.727e+03, 2.963e+03, 2.453e+03, 1.944e+03, 1.955e+03,
#         2.176e+03, 2.567e+03, 2.775e+03, 3.073e+03, 2.973e+03, 3.565e+03,
#         3.408e+03, 3.663e+03, 3.491e+03, 3.339e+03, 3.201e+03, 3.188e+03,
#         3.071e+03, 3.127e+03, 2.945e+03, 2.709e+03, 2.690e+03, 2.509e+03,
#         2.444e+03, 2.388e+03, 2.420e+03, 2.356e+03, 2.405e+03, 2.325e+03,
#         2.458e+03, 2.330e+03, 2.348e+03, 2.314e+03, 2.341e+03, 2.455e+03,
#         2.257e+03, 2.310e+03, 2.335e+03, 2.397e+03, 2.486e+03, 2.445e+03,
#         2.497e+03, 2.459e+03, 0.000e+00, 2.653e+03, 2.617e+03, 2.731e+03,
#         2.767e+03, 2.904e+03, 2.854e+03, 3.099e+03, 3.209e+03, 3.189e+03,
#         3.358e+03, 3.396e+03, 3.458e+03, 3.460e+03, 3.589e+03, 3.768e+03,
#         3.742e+03, 3.637e+03, 3.585e+03, 3.639e+03, 3.782e+03, 3.656e+03,
#         3.717e+03, 3.783e+03, 3.773e+03, 3.801e+03, 3.880e+03, 3.790e+03,
# ...

# %%
f = lambda x, y: np.sin(x) + np.cos(x + y)*np.cos(x)

# %%
X = np.linspace(0, 5, 100)
Y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(X, Y)

Z = f(X, Y)

# %% [markdown]
# ## Contours

# %%
# Visualisation du dessus, utile pour observer la minimasition du model, observer les minimums locaux et globaux
plt.contour(X, Y, Z, 20, colors='black') # Le niveau de profondeur et colors black, trait plein positif, tiret négatif
# plt.colorbar()

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %% [markdown]
# ## Imshow

# %% [markdown]
# Permet d’afficher n’importe quel tableau numpy.
#
#
# Peut être utile pour des matrices de corélations, problème d’optimisation…

# %%
iris = load_iris()

x = iris.data # 4 variables
y = iris.target # 150 exemples
names = list(iris.target_names)

x.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
plt.imshow(np.corrcoef(x.T), cmap='Blues')
plt.colorbar()

# %%
plt.imshow(Z)
